# %%
# helpers
import os 

# environment
from environment.puzzle_env import PuzzleEnv

# stable baselines
import gymnasium as gym 
from stable_baselines3 import PPO 
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# 2023-07-20 22:11:37.109748: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-20 22:11:37.744869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
load_path = os.path.join("training", "saved_models", "model")

# %%
model = PPO.load(load_path)

# %%
env = PuzzleEnv()
env.reset() 
env.render(render_mode='human')
evaluate_policy(model=model, env=env, n_eval_episodes=3)
env.close()
# Out:
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  4
# step_reward:  26.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  5
# step_reward:  25.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  6
# step_reward:  24.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  19
# step_reward:  11.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  10
# step_reward:  20.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  5
# step_reward:  25.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  12
# step_reward:  18.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  14
# step_reward:  16.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  11
# step_reward:  19.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  4
# step_reward:  26.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  4
# step_reward:  26.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  4
# step_reward:  26.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  12
# step_reward:  18.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  5
# step_reward:  25.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  11
# step_reward:  19.0
# holes:  9
# step_reward:  21.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  12
# step_reward:  18.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  7
# step_reward:  23.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  8
# step_reward:  22.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  7
# step_reward:  23.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 env.reset()
#       3 env.render(render_mode='human')
# ----> 4 evaluate_policy(model=model, env=env, n_eval_episodes=3)
#       5 env.close()
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/projects/rl_puzzle/environment/puzzle_env.py:174, in PuzzleEnv.step(self, action)
#     172 if (action == Actions.Nothing.value):
#     173     pass
# --> 174 self.__render__()
#     175 if self.board.move('down') == False:
#     176     step_reward += 10
#
# File ~/projects/rl_puzzle/environment/puzzle_env.py:230, in PuzzleEnv.__render__(self)
#     228                     pygame.draw.rect(self.screen, (255, 255, 255), (j * 30, i * 30, 30, 30))
#     229     pygame.display.flip()
# --> 230     self.clock.tick(self.tick_rate)
#     231 elif self.render_mode == "terminal":
#     232     print(self.__get_observation__())
#
# KeyboardInterrupt:
