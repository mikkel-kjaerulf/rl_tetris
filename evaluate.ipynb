# %%
# helpers
import os 

# environment
from environment.puzzle_env import PuzzleEnv

# stable baselines
import gymnasium as gym 
from stable_baselines3 import PPO 
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
load_path = os.path.join("training", "saved_models", "ent_reg_001_model")

# %%
model = PPO.load(load_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = PPO.load(load_path)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/base_class.py:679, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     676     print("== CURRENT SYSTEM INFO ==")
#     677     get_system_info()
# --> 679 data, params, pytorch_variables = load_from_zip_file(
#     680     path,
#     681     device=device,
#     682     custom_objects=custom_objects,
#     683     print_system_info=print_system_info,
#     684 )
#     686 assert data is not None, "No data found in the saved file"
#     687 assert params is not None, "No params found in the saved file"
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:390, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     363 def load_from_zip_file(
#     364     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     365     load_data: bool = True,
#    (...)
#     369     print_system_info: bool = False,
#     370 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     371     """
#     372     Load model data from a .zip archive
#     373
#    (...)
#     388         and dict of pytorch variables
#     389     """
# --> 390     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     392     # set device to cpu if cuda is not available
#     393     device = get_device(device=device)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:234, in open_path_str(path, mode, verbose, suffix)
#     219 @open_path.register(str)
#     220 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     221     """
#     222     Open a path given by a string. If writing to the path, the function ensures
#     223     that the path exists.
#    (...)
#     232     :return:
#     233     """
# --> 234     return open_path(pathlib.Path(path), mode, verbose, suffix)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:286, in open_path_pathlib(path, mode, verbose, suffix)
#     279         path.parent.mkdir(exist_ok=True, parents=True)
#     281 # if opening was successful uses the identity function
#     282 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     283 #   with corrections
#     284 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 286 return open_path(path, mode, verbose, suffix)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:266, in open_path_pathlib(path, mode, verbose, suffix)
#     264             path, suffix = newpath, None
#     265         else:
# --> 266             raise error
#     267 else:
#     268     try:
#
# File ~/miniconda3/envs/newenv/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:258, in open_path_pathlib(path, mode, verbose, suffix)
#     256 if mode == "r":
#     257     try:
# --> 258         path = path.open("rb")
#     259     except FileNotFoundError as error:
#     260         if suffix is not None and suffix != "":
#
# File ~/miniconda3/envs/newenv/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training/saved_models/ent_reg_001_model.zip'

# %%
env = PuzzleEnv()
env.reset() 
env.render(render_mode='human')
evaluate_policy(model=model, env=env, n_eval_episodes=3)
env.close()
# Out:
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  2
# step_reward after fit:  8
# step_reward after height:  5
# final step_reward:  5.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  5
# final step_reward:  5.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  3
# final step_reward:  3.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  6
# step_reward after fit:  4
# step_reward after height:  -4
# final step_reward:  -4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -2
# final step_reward:  -2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  2
# step_reward after fit:  8
# step_reward after height:  -5
# final step_reward:  -5.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  7
# final step_reward:  7.0
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  -6
# final step_reward:  -6.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  4
# step_reward after fit:  6
# step_reward after height:  2
# final step_reward:  2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  2
# final step_reward:  2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  11
# step_reward after fit:  -1
# step_reward after height:  -10
# final step_reward:  -10.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  10
# step_reward after fit:  0
# step_reward after height:  -11
# final step_reward:  -11.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  3
# step_reward after fit:  7
# step_reward after height:  -6
# final step_reward:  -6.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -5
# final step_reward:  -5.0
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -7
# final step_reward:  -7.0
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  -9
# final step_reward:  -9.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  6
# final step_reward:  6.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  4
# final step_reward:  4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  5
# step_reward after fit:  5
# step_reward after height:  -2
# final step_reward:  -2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  5
# step_reward after fit:  5
# step_reward after height:  -8
# final step_reward:  -8.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  1
# final step_reward:  1.0
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  20
# step_reward after fit:  -10
# step_reward after height:  -24
# final step_reward:  -24.0
# -----
# -----
# -----
# -----
# -----
# holes:  14
# step_reward after fit:  -4
# step_reward after height:  -20
# final step_reward:  -20.0
# -----
# -----
# -----
# -----
# holes:  16
# step_reward after fit:  -6
# step_reward after height:  -23
# final step_reward:  -23.0
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -11
# final step_reward:  -11.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  7
# final step_reward:  7.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  6
# step_reward after fit:  4
# step_reward after height:  -1
# final step_reward:  -1.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  4
# final step_reward:  4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  2
# final step_reward:  2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -1
# final step_reward:  -1.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  15
# step_reward after fit:  -5
# step_reward after height:  -17
# final step_reward:  -17.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  11
# step_reward after fit:  -1
# step_reward after height:  -15
# final step_reward:  -15.0
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  -6
# final step_reward:  -6.0
# -----
# -----
# -----
# -----
# holes:  14
# step_reward after fit:  -4
# step_reward after height:  -21
# final step_reward:  -21.0
# -----
# holes:  2
# step_reward after fit:  8
# step_reward after height:  -12
# final step_reward:  -12.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  8
# final step_reward:  8.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  6
# final step_reward:  6.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  5
# final step_reward:  5.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  3
# step_reward after fit:  7
# step_reward after height:  0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -2
# final step_reward:  -2.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  3
# step_reward after fit:  7
# step_reward after height:  -6
# final step_reward:  -6.0
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -6
# final step_reward:  -6.0
# -----
# -----
# -----
# -----
# -----
# holes:  14
# step_reward after fit:  -4
# step_reward after height:  -20
# final step_reward:  -20.0
# -----
# -----
# -----
# -----
# holes:  15
# step_reward after fit:  -5
# step_reward after height:  -22
# final step_reward:  -22.0
# -----
# -----
# -----
# holes:  15
# step_reward after fit:  -5
# step_reward after height:  -23
# final step_reward:  -23.0
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  -10
# final step_reward:  -10.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  8
# final step_reward:  8.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  2
# step_reward after fit:  8
# step_reward after height:  4
# final step_reward:  4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  3
# step_reward after fit:  7
# step_reward after height:  1
# final step_reward:  1.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  3
# final step_reward:  3.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -1
# final step_reward:  -1.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  1
# step_reward after fit:  9
# step_reward after height:  -4
# final step_reward:  -4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  18
# step_reward after fit:  -8
# step_reward after height:  -22
# final step_reward:  -22.0
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  13
# step_reward after fit:  -3
# step_reward after height:  -18
# final step_reward:  -18.0
# -----
# -----
# -----
# -----
# holes:  15
# step_reward after fit:  -5
# step_reward after height:  -22
# final step_reward:  -22.0
# -----
# -----
# holes:  18
# step_reward after fit:  -8
# step_reward after height:  -27
# final step_reward:  -27.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  7
# final step_reward:  7.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  3
# step_reward after fit:  7
# step_reward after height:  1
# final step_reward:  1.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  7
# step_reward after fit:  3
# step_reward after height:  -4
# final step_reward:  -4.0
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# holes:  0
# step_reward after fit:  10
# step_reward after height:  1
# final step_reward:  1.0
# -----
# -----
# -----
# -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 4
#       2 env.reset()
#       3 env.render(render_mode='human')
# ----> 4 evaluate_policy(model=model, env=env, n_eval_episodes=10)
#       5 env.close()
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/projects/rl_puzzle/environment/puzzle_env.py:176, in step(self, action)
#     174         print("-----")
#     175 if (action == Actions.MoveRight.value):
# --> 176     self.board.move('right')
#     177 if (action == Actions.MoveLeft.value):
#     178     self.board.move('left')
#
# File ~/projects/rl_puzzle/environment/puzzle_env.py:243, in __render__(self)
#     241         if [y, x] in self.board.__get_locked_positions__().tolist():
#     242             break
# --> 243         if self.board.field[y, x] == 0:
#     244             holes += 1
#     245 if self.render_mode == "human":
#
# KeyboardInterrupt:
