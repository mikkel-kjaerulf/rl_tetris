# %%
# helpers
import os 

# environment
from environment.puzzle_env import PuzzleEnv

# stable baselines
import gymnasium as gym 
from stable_baselines3 import PPO 
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
load_path = os.path.join("training", "saved_models", "model")

# %%
model = PPO.load(load_path)

# %%
env = PuzzleEnv()
env.reset() 
env.render(render_mode='human')
evaluate_policy(model=model, env=env, n_eval_episodes=3)
env.close()
# Out:
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  6
# step_reward:  24.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  9
# step_reward:  21.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  15
# step_reward:  15.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  9
# step_reward:  21.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  6
# step_reward:  24.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  3
# step_reward:  27.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  4
# step_reward:  26.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  5
# step_reward:  25.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  1
# step_reward:  29.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  6
# step_reward:  24.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  2
# step_reward:  28.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# step_reward:  0.0
# step_reward:  0.0
# holes:  0
# step_reward:  30.0
# holes:  4
# step_reward:  26.0
